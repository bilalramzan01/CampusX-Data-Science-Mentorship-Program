# %% [markdown]
# ## Modules
#
# module is a file having different function in it for use, we can just import and use that module.
#
# - Math
# - keywords
# - Date time
# - random

# %% [markdown]
# #### Math

# %%
import math

math.factorial(5)
# Out:
# 120

# %%
math.floor(6.9)
# Out:
# 6

# %%
math.sqrt(120)
# Out:
# 10.954451150103322

# %% [markdown]
# ### Keywords

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ### Random

# %%
import random

# %%
random.randint(1,100)
# Out:
# 59

# %% [markdown]
# ### Date and Time

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 7, 31, 23, 48, 51, 729920)

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             charset_normalizer  matplotlib_inline   signal
# OpenSSL             click               mccabe              sipbuild
# PIL                 cloudpickle         mdit_py_plugins     site
# PyQt5               cmath               mdurl               six
# PySide6             cmd                 menuinst            skimage
# __future__          code                mimetypes           sklearn
# __hello__           codecs              minify_html         slugify
# __phello__          codeop              mistune             smmap
# _abc                collections         mkl                 smtplib
# _aix_support        colorama            mkl_fft             sniffio
# _android_support    colorcet            mkl_random          snowballstemmer
# _apple_support      colorsys            mlxtend             socket
# _argon2_cffi_bindings comm                mmap                socketserver
# ...
