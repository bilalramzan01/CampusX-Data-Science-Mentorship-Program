# %% [markdown]
# ### Tuple
# - Tuple in python is similar to list.
# - immuteable
# - ordered
# - Allows duplications
# - created in () brackets

# %%
t = (1,2,3,4,5)

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# #### Creating tuples

# %%
# Empty tuple
t = ()

# %%
t
# Out:
# ()

# %%
t2 = (2)

# %%
type(t2)
# Out:
# int

# %%
# Single item
t3 = (2,)

# %%
t3
# Out:
# (2,)

# %%
type(t3)
# Out:
# tuple

# %%
# hetrogenius

t4 = (1,2,3,'Bilal')

# %%
t4
# Out:
# (1, 2, 3, 'Bilal')

# %%
t5 = (1,2,3,4,(23,45))

# %%
t5
# Out:
# (1, 2, 3, 4, (23, 45))

# %%
t6 = tuple('Hello')

# %%
t6
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %% [markdown]
# ### Accesssing items

# %%
t = (1,2,3,4,5)

# %%
t[1]
# Out:
# 2

# %%
t[-3]
# Out:
# 3

# %%
t[2:4]
# Out:
# (3, 4)

# %%
t[-4:-1]
# Out:
# (2, 3, 4)

# %%
t[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
# Immuteable
t[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Immuteable
# ----> 2 t[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Addition not possible

# %%
t = (1,2,3,4,5)

# %%
del t[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 del t[3]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
del t

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 t
#
# NameError: name 't' is not defined

# %% [markdown]
# ### Operations and functions

# %%
t1 = (1,2,3)
t2 = (4,5,6)

# %%
t1+t2
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t1*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
2 in t2
# Out:
# False

# %%
2 in t1
# Out:
# True

# %%
for i in t1:
    print(i)
# Out:
# 1
# 2
# 3

# %%
len(t1)
# Out:
# 3

# %%
min(t1)
# Out:
# 1

# %%
max(t1)
# Out:
# 3

# %%
sum(t1)
# Out:
# 6

# %%
sorted(t1, reverse = True)
# Out:
# [3, 2, 1]

# %%
t1.count(2)
# Out:
# 1

# %%
t1.index(1)
# Out:
# 0

# %%
a = (1,2,3)
a,b,c = a

# %%
a,b,c
# Out:
# (1, 2, 3)

# %%
a = (1,2,3,4,5)
a,b,*others = a

# %%
others
# Out:
# [3, 4, 5]

# %% [markdown]
# ## Zipping
#
# make pairs from both lists or tuples

# %%
t1 = (1,2,3)
t2 = (4,5,6)

# %%
list(zip(t1,t1))
# Out:
# [(1, 1), (2, 2), (3, 3)]
