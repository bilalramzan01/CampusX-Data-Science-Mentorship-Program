# %% [markdown]
# ### What is Python?
# Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.
#
# **It is used for:**
#
# - web development (server-side),
# - software development,
# - mathematics,
# - system scripting.
# - Case senstive language
#
# ### What can Python do?
#
# - Python can be used on a server to create web applications.
# - Python can be used alongside software to create workflows.
# - Python can connect to database systems. It can also read and modify files.
# - Python can be used to handle big data and perform complex mathematics.
# - Python can be used for rapid prototyping, or for production-ready software development.
#
# ### Why Python?
# - Design philosophy (Easy to use, easy syntax)
# - Awesome community
# - Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
# - Python has a simple syntax similar to the English language.
# - Python has syntax that allows developers to write programs with fewer lines than some other programming languages.
# - Python runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick.
# - Python can be treated in a procedural way, an object-oriented way or a functional way.

# %% [markdown]
# ### why python for Data Science
# - Easy to learn for various domains people
# - Proximaty with mathematics. Like python have many libraries for math like numpy
# - Community, echosytem, libraries

# %% [markdown]
# ## 1. Python Output

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print(10)
# Out:
# 10

# %%
print(10.10)
# Out:
# 10.1

# %%
# multiple things can be printed which will be separated by space
print('hello',1,10.1,2)
# Out:
# hello 1 10.1 2

# %%
print(10)
print("Hello")
# Out:
# 10
# Hello

# %% [markdown]
# ## 2. Data Types

# %% [markdown]
# #### 1. Integers

# %%
# python can handle larnge number of integers

# %%
print(10*4783^89)
# Out:
# 47759

# %% [markdown]
# #### 2. decimal/float

# %%
print(10.45)
# Out:
# 10.45

# %% [markdown]
# #### 3. Boolean

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# #### 4. Text/String

# %%
print("This is a string")
print('This is also a string')
# Out:
# This is a string
# This is also a string

# %% [markdown]
# #### 5.Complex number

# %%
print(5+6j)
# Out:
# (5+6j)

# %% [markdown]
# #### 6.List

# %%
print([10,2,3,5,3,5])
# Out:
# [10, 2, 3, 5, 3, 5]

# %% [markdown]
# #### 7.Tuple

# %%
print((12,3,5,654))
# Out:
# (12, 3, 5, 654)

# %% [markdown]
# #### 8.Sets

# %%
print({12,43,65436,65,24})
# Out:
# {65, 24, 65436, 43, 12}

# %% [markdown]
# #### 9.Dictionary

# %%
print({'name':'Bilal', 'No':15})
# Out:
# {'name': 'Bilal', 'No': 15}

# %% [markdown]
# ## 3. Variables
#
# - Containers used to store data

# %%
a = 5
print(a)
# Out:
# 5

# %%
name = 'Bilal'
print(name)
# Out:
# Bilal

# %% [markdown]
# ### Dynamic Typing
#
# - Creating variable without tell the data type of variable unlike c++, this is called dynamic typing
#
# ### Static Typing
# - declaring data type when creating variable

# %% [markdown]
# ### Dynamic Binding
#
# - one variable can hold multiple data types like a having 5 and alos a having 'Bilal'.
#
# ### Static binding
#
# - one variable can hold only one data type through out the program

# %%
#### Decalring multiple variables

a,b,c,d=12,34,66,77

# %%
print(a,b,c)
# Out:
# 12 34 66

# %%
#one value in multiple variables
a=b=c=10
print(a)
# Out:
# 10

# %% [markdown]
# ## Keywords and identifiers

# %% [markdown]
# #### Compilation
# - process to convert programming or high level language to machine or binary language
#
# #### Compiler
# - Compile the whole program at one like java and c++
#
# #### Interpreter
# - compile the code line by line like python
# -

# %% [markdown]
# ### Keywords:
# Specific words that is reserved for the python or langauge and are not allowed to use as variable.

# %% [markdown]
# ## Identifiers
# - Names given by programmers to identified their function class or variables.
# #### Rules for naming identifier:
# - You cant start with digit
# - you can use upper case lower case and numbers but in special character _ this can be used.
# - idetifiers cannot be keywords
# -

# %% [markdown]
# # User Inputs

# %%
name = input("Enter Your name:")
print('My name is',name)
# Out:
# Enter Your name: Bilal Ramzan
# My name is Bilal Ramzan

# %%
num1 = input('Enter first number:')
num2 = input('Enter second number:')
sum = num1 + num2
print('Sum of numbers is:', sum)
# Out:
# Enter first number: 15
# Enter second number: 56
# Sum of numbers is: 1556

# %% [markdown]
# ## Type conversion
#
# 1. Implicit (when python automatically detect data type while operation like 5 + 5.10, python add even differ data type)
# 2. explicit (conversion using functions. str -> int. int(4). But all conversion not allowed. it allowed when possible

# %%
# By default input is inetgers
# so we have to change or decalre the data type

# %%
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
sum = num1 + num2
print('Sum of numbers is:', sum)
type(num1)
# Out:
# Enter first number: 23
# Enter second number: 43
# Sum of numbers is: 66
# int

# %% [markdown]
# ## Literals
#
# Raw values stored in the variable
#
# - **Binary literals** a = 0b1010
# - **Decimal literals** b = 100
# - **Octal literals** c = 0o310
# - **Hexadecimal literals** d = 0x12c
# - **Float Literals** e = 10.5,1.5e3,1.5e-3
# - **Complex literals** f = 3.13j
# - **Strings** g = 'Bilal', "Bilal"
# - **Char** h = "C"
# - **unicode** u"\u1006700/U000698/U38383"
# - **raw_string** r"raw \n string"

# %% [markdown]
# #### Bolean
#
# is treated as number in python. True is 1 and False is 0.

# %% [markdown]
# #### None
#
# - none means nothing
# - none is use when need variabe having no value, because only decalartion is not allowed

# %%
a = None
print(a)
# Out:
# None

# %%
#
