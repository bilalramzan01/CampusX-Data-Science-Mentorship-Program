# %% [markdown]
# ## What is Pandas.
#
# It is a fast, flexible, power full open source library for data analysis and data manupulation.
# You can do any kind of analysis using pandas.

# %% [markdown]
# ### Pandas have two objects:
# 1. Pandas series
# 2. DataFrame Pandas

# %% [markdown]
# ### Pandas Series
# Pandas series is like a columns in a table. It is 1D array holding data of any type.

# %%
import numpy as np
import pandas as pd

# %%
# Create a list of array ( countries list)

country = ['Pakistan', 'India','Nepal','USA','Afghanistan','Italy']

# %%
# Make series of countries

# %%
pd.Series(country)
# Out:
# 0       Pakistan
# 1          India
# 2          Nepal
# 3            USA
# 4    Afghanistan
# 5          Italy
# dtype: object

# %%
# dtype = object ( Means that pandas called string as object datatype)

# %%
runs = [1,3,65,45,76,356]

# %%
pd.Series(runs)
# Out:
# 0      1
# 1      3
# 2     65
# 3     45
# 4     76
# 5    356
# dtype: int64

# %%
# Index is starting from 0, we can give our own index

# %%
# Custom index

marks = [45,32,54,75,86]
subjects = ['Maths', 'Science', 'Urdu', 'computer', 'Physics']

# %%
pd.Series(marks, index=subjects)
# Out:
# Maths       45
# Science     32
# Urdu        54
# computer    75
# Physics     86
# dtype: int64

# %%
pd.Series(marks, index=subjects, name='Mine marks')
# Out:
# Maths       45
# Science     32
# Urdu        54
# computer    75
# Physics     86
# Name: Mine marks, dtype: int64

# %%
marks = pd.Series(marks, index=subjects, name='Mine marks')

# %%
marks
# Out:
# Maths       45
# Science     32
# Urdu        54
# computer    75
# Physics     86
# Name: Mine marks, dtype: int64

# %% [markdown]
# ### Making series using dict

# %%
marks = {
    'maths':63,
    'Physics':83,
    'Computer':76,
    'Urdu':99
}

# %%
marks
# Out:
# {'maths': 63, 'Physics': 83, 'Computer': 76, 'Urdu': 99}

# %%
marks_series = pd.Series(marks, name='Bilal Ramzan')

# %%
marks_series
# Out:
# maths       63
# Physics     83
# Computer    76
# Urdu        99
# Name: Bilal Ramzan, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# 'Bilal Ramzan'

# %%
marks_series.is_unique
# Out:
# True

# %%
marks_series.index
# Out:
# Index(['maths', 'Physics', 'Computer', 'Urdu'], dtype='object')

# %%
marks_series.values
# Out:
# array([63, 83, 76, 99])

# %%
## Series using existing data set ( CSV)

# %%
df = pd.read_csv('Datasets/subs.csv')

# %%
df
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# By default the data is stored in DataFrame (Convert it into series.

# %%
df = pd.read_csv('Datasets/subs.csv').squeeze()

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('Datasets/kohli_ipl.csv', index_col='match_no').squeeze()

# %%
type(vk)
# Out:
# pandas.core.series.Series

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
b = pd.read_csv('Datasets/bollywood.csv', index_col='movie')

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b = pd.read_csv('Datasets/bollywood.csv', index_col='movie').squeeze()

# %%
type(b)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Imp Series Methods

# %% [markdown]
# #### 1. Head and tail method
# give the first and last parts of data

# %%
b.head()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
b.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
b.sample(5)
# Out:
# movie
# Singh Is Kinng                  Akshay Kumar
# Munna Bhai M.B.B.S.              Sanjay Dutt
# My Bollywood Bride               Jason Lewis
# Laila Majnu (2018 film)       Avinash Tiwary
# Hawaa Hawaai               Makrand Deshpande
# Name: lead, dtype: object

# %% [markdown]
# ### Value_counts
# tells the frequency rate/count (How much time the values come in the data)

# %%
b.value_counts()
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
#                       ..
# Talha Arshad Reshi     1
# Garima Agarwal         1
# Rasika Agashe          1
# Zaheer Iqbal           1
# Deepika Amin           1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# ### Sort_values
# sort all the values

# %%
b.sort_values()
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
b.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
vk = pd.read_csv('Datasets/kohli_ipl.csv', index_col='match_no').squeeze()

# %%
vk.sort_values(ascending=False).head().values[0]
# Out:
# np.int64(113)

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# vk.sort_values(inplace=True)

# %%
b
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# Sort indexing ( As index is movies name, the moavies name sorted from numbers then A-Z)
b.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# b.sort_values()

# %% [markdown]
# ### Series math methods
# - count missing values as well

# %%
# count missing values as well
vk.count()
# Out:
# np.int64(215)

# %%
# Do not count missing values
vk.size
# Out:
# 215

# %%
subs = pd.read_csv('Datasets/subs.csv')

# %%
subs.count()
# Out:
# Subscribers gained    365
# dtype: int64

# %%
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
subs.min()
# Out:
# Subscribers gained    33
# dtype: int64

# %%
subs.max()
# Out:
# Subscribers gained    396
# dtype: int64

# %%
subs.median()
# Out:
# Subscribers gained    123.0
# dtype: float64

# %%
# Most value comes in the data
subs.mode()
# Out:
#    Subscribers gained
# 0                 105

# %%
b.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
subs.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
vk.var()
# Out:
# 688.0024777222344

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
vk.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int64
# dtypes: int64(1)
# memory usage: 3.4 KB

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %% [markdown]
# ### Series indexing

# %%
# Seies only work on positive indexing
x = pd.Series([1,2,4,5,3,5,7,7654,23])

# %%
x
# Out:
# 0       1
# 1       2
# 2       4
# 3       5
# 4       3
# 5       5
# 6       7
# 7    7654
# 8      23
# dtype: int64

# %%
x[5]
# Out:
# np.int64(5)

# %%
# Slicing in series of pandas

# %%
vk[5:25]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# 17    22
# 18    19
# 19    16
# 20    15
# 21    20
# 22    38
# 23    19
# 24    24
# 25     7
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
b[-5::2]
# Out:
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Saathiya (film)             Vivek Oberoi
# Awara Paagal Deewana        Akshay Kumar
# Name: lead, dtype: object

# %% [markdown]
# #### Fancy indexing

# %%
vk[[2,3,5,7,4]]
# Out:
# match_no
# 2    23
# 3    13
# 5     1
# 7    34
# 4    12
# Name: runs, dtype: int64

# %% [markdown]
# ### Label fetching

# %%
b['Saathiya (film)']
# Out:
# 'Vivek Oberoi'

# %%
vk[34]
# Out:
# np.int64(58)

# %% [markdown]
# ### How can be edit items in series

# %%
marks
# Out:
# {'maths': 100,
#  'Physics': 83,
#  'Computer': 76,
#  'Urdu': 99,
#  0: 85,
#  'Social Studies': 85}

# %%
marks['maths'] = 100

# %%
runs = [1,3,65,45,76,356]

# %%
runs
# Out:
# [1, 3, 65, 45, 76, 356]

# %%
x = pd.Series(runs)

# %%
x
# Out:
# 0      1
# 1      3
# 2     65
# 3     45
# 4     76
# 5    356
# dtype: int64

# %%
x[2:4] = [100,100]

# %%
x
# Out:
# 0      1
# 1      3
# 2    100
# 3    100
# 4     76
# 5    356
# dtype: int64

# %%
len(subs)
# Out:
# 365

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
dir(b)
# Out:
# ['Aiyaary',
#  'Amavas',
#  'Bombairiya',
#  'Hichki',
#  'Jhalki',
#  'Kaalakaandi',
#  'Kalank',
#  'Marjaavaan',
#  'Mukkabaaz',
#  'Nirdosh',
#  'Padmaavat',
#  'Pranaam',
#  'Prassthanam',
#  'Risknamaa',
#  'Saaho',
#  'Sonchiriya',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
# ...

# %%
subs.isnull().sum()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
subs.mask
# Out:
# <bound method NDFrame.mask of      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]>

# %%
list(marks)
# Out:
# ['maths',
#  'Physics',
#  'Computer',
#  'Urdu',
#  0,
#  'Social Studies',
#  slice(2, 5, None),
#  slice('maths', 'Physics', 'Computer')]

# %%
dict(marks)
# Out:
# {'maths': 100,
#  'Physics': 83,
#  'Computer': 76,
#  'Urdu': 99,
#  0: 85,
#  'Social Studies': 85,
#  slice(2, 5, None): [80, 80, 80],
#  slice('maths', 'Physics', 'Computer'): [80, 80, 80]}
